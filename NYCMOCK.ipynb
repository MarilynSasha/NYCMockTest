# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 999
from scipy import stats
np.random.seed(seed=42)
from collections import Counter
import os

# %%
#loading data 
cdcmh = pd.read_csv("/Users/TheUnit/Desktop/U.S._Chronic_Disease_Indicators__Mental_Health.csv")

# %%
cdcmh
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0           2017     2017           AZ        Arizona      BRFSS
# 1           2012     2012           AR       Arkansas      BRFSS
# 2           2011     2011           FL        Florida      BRFSS
# 3           2018     2018           GA        Georgia      BRFSS
# 4           2016     2016           ID          Idaho      BRFSS
# ...          ...      ...          ...            ...        ...
# 10805       2012     2012           NH  New Hampshire      BRFSS
# 10806       2019     2019           NJ     New Jersey      BRFSS
# 10807       2015     2015           MT        Montana      BRFSS
# 10808       2019     2019           MO       Missouri      BRFSS
# 10809       2014     2014           KS         Kansas      BRFSS
#
#                Topic                                           Question  \
# 0      Mental Health  Recent mentally unhealthy days among adults ag...
# ...

# %%
cdcmh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10810 entries, 0 to 10809
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  10810 non-null  int64
#  1   YearEnd                    10810 non-null  int64
#  2   LocationAbbr               10810 non-null  object
#  3   LocationDesc               10810 non-null  object
#  4   DataSource                 10810 non-null  object
#  5   Topic                      10810 non-null  object
#  6   Question                   10810 non-null  object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              10810 non-null  object
#  9   DataValueType              10810 non-null  object
#  10  DataValue                  8617 non-null   float64
#  11  DataValueAlt               8617 non-null   float64
#  12  DataValueFootnoteSymbol    2256 non-null   object
# ...

# %%
cdcmh.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'ResponseID', 'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID',
#        'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
cdcmh.groupby('DataSource').count()
# Out:
#             YearStart  YearEnd  LocationAbbr  LocationDesc  Topic  Question  \
# DataSource
# BRFSS           10755    10755         10755         10755  10755     10755
# PRAMS              55       55            55            55     55        55
#
#             Response  DataValueUnit  DataValueType  DataValue  ...  \
# DataSource                                                     ...
# BRFSS              0          10755          10755       8594  ...
# PRAMS              0             55             55         23  ...
#
#             LocationID  TopicID  QuestionID  DataValueTypeID  \
# DataSource
# BRFSS            10755    10755       10755            10755
# PRAMS               55       55          55               55
#
#             StratificationCategoryID1  StratificationID1  \
# DataSource
# BRFSS                           10755              10755
# PRAMS                              55                 55
#
#             StratificationCategoryID2  StratificationID2  \
# ...

# %%
cdcmh.groupby('Question').count()
# Out:
#                                                     YearStart  YearEnd  \
# Question
# At least 14 recent mentally unhealthy days amon...       2925     2925
# Postpartum depressive symptoms                             55       55
# Recent mentally unhealthy days among adults age...       7830     7830
#
#                                                     LocationAbbr  \
# Question
# At least 14 recent mentally unhealthy days amon...          2925
# Postpartum depressive symptoms                                55
# Recent mentally unhealthy days among adults age...          7830
#
#                                                     LocationDesc  DataSource  \
# Question
# At least 14 recent mentally unhealthy days amon...          2925        2925
# Postpartum depressive symptoms                                55          55
# Recent mentally unhealthy days among adults age...          7830        7830
#
#                                                     Topic  Response  \
# ...

# %%
cdcmh.groupby('LocationDesc').count()
# Out:
#                       YearStart  YearEnd  LocationAbbr  DataSource  Topic  \
# LocationDesc
# Alabama                     199      199           199         199    199
# Alaska                      199      199           199         199    199
# Arizona                     199      199           199         199    199
# Arkansas                    199      199           199         199    199
# California                  199      199           199         199    199
# Colorado                    199      199           199         199    199
# Connecticut                 199      199           199         199    199
# Delaware                    199      199           199         199    199
# District of Columbia        199      199           199         199    199
# Florida                     199      199           199         199    199
# Georgia                     199      199           199         199    199
# ...

# %%
AL = cdcmh[(cdcmh['LocationDesc'] == 'Alabama') ]

# %%
AL
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 41          2009     2011           AL      Alabama      PRAMS  Mental Health
# 84          2018     2018           AL      Alabama      BRFSS  Mental Health
# 236         2017     2017           AL      Alabama      BRFSS  Mental Health
# 292         2019     2019           AL      Alabama      BRFSS  Mental Health
# 306         2019     2019           AL      Alabama      BRFSS  Mental Health
# 535         2014     2014           AL      Alabama      BRFSS  Mental Health
# 542         2018     2018           AL      Alabama      BRFSS  Mental Health
# 559         2017     2017           AL      Alabama      BRFSS  Mental Health
# 692         2015     2015           AL      Alabama      BRFSS  Mental Health
# 793         2016     2016           AL      Alabama      BRFSS  Mental Health
# 828         2013     2013           AL      Alabama      BRFSS  Mental Health
# ...

# %%
AL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 41 to 10757
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  199 non-null    int64
#  1   YearEnd                    199 non-null    int64
#  2   LocationAbbr               199 non-null    object
#  3   LocationDesc               199 non-null    object
#  4   DataSource                 199 non-null    object
#  5   Topic                      199 non-null    object
#  6   Question                   199 non-null    object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              199 non-null    object
#  9   DataValueType              199 non-null    object
#  10  DataValue                  159 non-null    float64
#  11  DataValueAlt               159 non-null    float64
#  12  DataValueFootnoteSymbol    40 non-null     object
# ...

# %%
SC = cdcmh[(cdcmh['LocationDesc'] == 'South Carolina') ]

# %%
SC
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 33          2009     2011           SC  South Carolina      PRAMS
# 186         2019     2019           SC  South Carolina      BRFSS
# 246         2014     2014           SC  South Carolina      BRFSS
# 272         2012     2012           SC  South Carolina      BRFSS
# 466         2018     2018           SC  South Carolina      BRFSS
# 508         2014     2014           SC  South Carolina      BRFSS
# 541         2019     2019           SC  South Carolina      BRFSS
# 560         2019     2019           SC  South Carolina      BRFSS
# 649         2013     2013           SC  South Carolina      BRFSS
# 663         2011     2011           SC  South Carolina      BRFSS
# 697         2017     2017           SC  South Carolina      BRFSS
# 812         2015     2015           SC  South Carolina      BRFSS
# 845         2018     2018           SC  South Carolina      BRFSS
# ...

# %%
SC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 33 to 10803
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  199 non-null    int64
#  1   YearEnd                    199 non-null    int64
#  2   LocationAbbr               199 non-null    object
#  3   LocationDesc               199 non-null    object
#  4   DataSource                 199 non-null    object
#  5   Topic                      199 non-null    object
#  6   Question                   199 non-null    object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              199 non-null    object
#  9   DataValueType              199 non-null    object
#  10  DataValue                  173 non-null    float64
#  11  DataValueAlt               173 non-null    float64
#  12  DataValueFootnoteSymbol    26 non-null     object
# ...

# %%
cdcmh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10810 entries, 0 to 10809
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  10810 non-null  int64
#  1   YearEnd                    10810 non-null  int64
#  2   LocationAbbr               10810 non-null  object
#  3   LocationDesc               10810 non-null  object
#  4   DataSource                 10810 non-null  object
#  5   Topic                      10810 non-null  object
#  6   Question                   10810 non-null  object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              10810 non-null  object
#  9   DataValueType              10810 non-null  object
#  10  DataValue                  8617 non-null   float64
#  11  DataValueAlt               8617 non-null   float64
#  12  DataValueFootnoteSymbol    2256 non-null   object
# ...

# %%
US = cdcmh[(cdcmh['LocationDesc'] == 'United States') ]

# %%
US
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 34          2009     2011           US  United States      PRAMS
# 85          2014     2014           US  United States      BRFSS
# 588         2018     2018           US  United States      BRFSS
# 755         2016     2016           US  United States      BRFSS
# 830         2015     2015           US  United States      BRFSS
# 895         2013     2013           US  United States      BRFSS
# 942         2016     2016           US  United States      BRFSS
# 1043        2012     2012           US  United States      BRFSS
# 1097        2018     2018           US  United States      BRFSS
# 1573        2018     2018           US  United States      BRFSS
# 1682        2012     2012           US  United States      BRFSS
# 2144        2014     2014           US  United States      BRFSS
# 2311        2017     2017           US  United States      BRFSS
# ...

# %%
US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 34 to 10695
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  64 non-null     int64
#  1   YearEnd                    64 non-null     int64
#  2   LocationAbbr               64 non-null     object
#  3   LocationDesc               64 non-null     object
#  4   DataSource                 64 non-null     object
#  5   Topic                      64 non-null     object
#  6   Question                   64 non-null     object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              64 non-null     object
#  9   DataValueType              64 non-null     object
#  10  DataValue                  63 non-null     float64
#  11  DataValueAlt               63 non-null     float64
#  12  DataValueFootnoteSymbol    64 non-null     object
# ...

# %%
cdcmh.groupby('StratificationCategory1').count()
# Out:
#                          YearStart  YearEnd  LocationAbbr  LocationDesc  \
# StratificationCategory1
# Gender                        1980     1980          1980          1980
# Overall                       1540     1540          1540          1540
# Race/Ethnicity                7290     7290          7290          7290
#
#                          DataSource  Topic  Question  Response  DataValueUnit  \
# StratificationCategory1
# Gender                         1980   1980      1980         0           1980
# Overall                        1540   1540      1540         0           1540
# Race/Ethnicity                 7290   7290      7290         0           7290
#
#                          DataValueType  ...  LocationID  TopicID  QuestionID  \
# StratificationCategory1                 ...
# Gender                            1980  ...        1980     1980        1980
# Overall                           1540  ...        1540     1540        1540
# ...

# %%
cdcmh.groupby('StratificationID1').count()
# Out:
#                    YearStart  YearEnd  LocationAbbr  LocationDesc  DataSource  \
# StratificationID1
# BLK                     1458     1458          1458          1458        1458
# GENF                     990      990           990           990         990
# GENM                     990      990           990           990         990
# HIS                     1458     1458          1458          1458        1458
# MRC                     1458     1458          1458          1458        1458
# OTH                     1458     1458          1458          1458        1458
# OVR                     1540     1540          1540          1540        1540
# WHT                     1458     1458          1458          1458        1458
#
#                    Topic  Question  Response  DataValueUnit  DataValueType  \
# StratificationID1
# BLK                 1458      1458         0           1458           1458
# GENF                 990       990         0            990            990
# ...
